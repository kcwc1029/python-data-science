# %%
import pandas as pd


### 建立訂單資料
orders_data = {
    "訂單編號": ["A001", "A002", "A003", "A004"],
    "店家編號": ["S01", "S02", "S01", "S03"],
    "金額": [180, 320, 250, 450]
}

orders = pd.DataFrame(orders_data)

### 建立店家資料
shops_data = {
    "店家編號": ["S01", "S02", "S03"],
    "店家名稱": ["阿明便當", "珍珠奶茶店", "老王牛肉麵"],
    "類別": ["便當", "飲料", "麵食"]
}

shops = pd.DataFrame(shops_data)


# 現在兩張表都有「店家編號」，所以可以使用它當作合併依據。
### 使用店家編號合併兩張資料表
result = orders.merge(
    shops,
    on="店家編號"
)

print(result)
# Out:
#    訂單編號 店家編號   金額   店家名稱  類別
# 0  A001  S01  180   阿明便當  便當
# 1  A002  S02  320  珍珠奶茶店  飲料
# 2  A003  S01  250   阿明便當  便當
# 3  A004  S03  450  老王牛肉麵  麵食

# %% [markdown]
# ### how：決定怎麼合併
#
# merge() 有一個`how`參數，用來決定「如果兩張表的資料沒有完全對得上，要留下哪些資料？」
#
# 常見有四種：
#
# | `how`     | 意義                 |
# | --------- | -------------------- |
# | `"inner"` | 只保留兩邊都有的資料 |
# | `"left"`  | 左表全部保留         |
# | `"right"` | 右表全部保留         |
# | `"outer"` | 左右兩邊全部保留     |

# %%
import pandas as pd


### 建立訂單資料
orders_data = {
    "訂單編號": ["A001", "A002", "A003", "A004"],
    "店家編號": ["S01", "S02", "S01", "S99"],
    "金額": [180, 320, 250, 450]
}

orders = pd.DataFrame(orders_data)

### 建立店家資料
shops_data = {
    "店家編號": ["S01", "S02", "S03"],
    "店家名稱": ["阿明便當", "珍珠奶茶店", "老王牛肉麵"],
    "類別": ["便當", "飲料", "麵食"]
}

shops = pd.DataFrame(shops_data)


# 現在兩張表都有「店家編號」，所以可以使用它當作合併依據。
### 使用店家編號合併兩張資料表
result = orders.merge(
    shops,
    on="店家編號"
)

### Inner Join
result_Inner = orders.merge(
    shops,
    on="店家編號",
    how="inner"
)

print(result_Inner) # Pandas 找不到 S99，所以 A004 不會出現在結果中。


### Left Join
result_Left = orders.merge(
    shops,
    on="店家編號",
    how="left"
)
# orders ← 全部保留
# shops  ← 有對到就補進來

print(result_Left) # S99會跑出一筆新的資料


### Outer Join
result_Outer = orders.merge(
    shops,
    on="店家編號",
    how="outer"
)

print(result_Outer)
