# %% [markdown]
# ### Problem. 讀取飲料訂單 CSV
#
# 請讀取`../pandas_datasets/drinks.csv`，並完成：
#
# - 顯示完整資料。
# - 顯示前 3 筆資料。
# - 顯示資料的欄位名稱。

# %% [markdown]
# ### Problem. 計算訂單金額並匯出 CSV
#
# 請讀取`../pandas_datasets/drinks.csv`，請新增一個「總金額」欄位：
# ```
# 總金額 = 價格 × 數量
# ```
# 完成後，將結果儲存成 drinks_result.csv
#
# 要求：
# - 不要輸出 DataFrame 的 index。
# - 使用 utf-8-sig 編碼，讓 Excel 開啟中文 CSV 時比較不容易出現亂碼。

# %% [markdown]
# ### Problem. 讀取學生成績 Excel
#
# 請讀取`../pandas_datasets/scores.xlsx`，請完成：
# - 使用 pd.read_excel() 讀取 scores.xlsx。
# - 指定讀取「期中考」工作表。
# - 顯示完整資料。
# - 新增「平均」欄位。

# %% [markdown]
# ### Problem. 找出及格學生並匯出 Excel
#
# 延續第 3 題的成績資料。請找出「平均 >= 60」的學生，並將結果儲存成pass_students.xlsx。
#
# 工作表名稱設定為「及格名單」

# %% [markdown]
# ### Problem. CSV → Excel 資料格式轉換
#
# 請完成：
# - 使用 Pandas 讀取 expenses.csv。
# - 顯示資料，確認讀取成功。
# - 將資料匯出成 expenses.xlsx。
# - Excel 工作表名稱設定為「支出紀錄」。
# - 不要輸出 index。
